# %%
import re
import string
from collections import Counter
import numpy as np

# %%
def read_corpus(filename):
  with open(filename, "r") as file:
    lines = file.readlines()
    words = []
    for line in lines:
      words += re.findall(r'\w+', line.lower())

  return words

# %%
words = read_corpus("/content/demo.txt")
print(f"There are {len(words)} total words in the corpus")
# Out:
# There are 16 total words in the corpus

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 15 unique words in the vocabulary

# %%
word_counts = Counter(words)
print(word_counts["play"])
# Out:
# 1

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
# prob= freq of that word/ count of all words in corpus

# %%
word_counts['play']
# Out:
# 1

# %%
print(word_probas["play"])
# Out:
# 0.0625

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("trash"))
# Out:
# [('', 'trash'), ('t', 'rash'), ('tr', 'ash'), ('tra', 'sh'), ('tras', 'h'), ('trash', '')]

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r] # list comprehension

# %%
print(delete("trash"))
# Out:
# ['rash', 'tash', 'trsh', 'trah', 'tras']

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("trash"))
# Out:
# ['rtash', 'tarsh', 'trsah', 'trahs']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("trash")) # with each alphabet letter
# Out:
# ['arash', 'brash', 'crash', 'drash', 'erash', 'frash', 'grash', 'hrash', 'irash', 'jrash', 'krash', 'lrash', 'mrash', 'nrash', 'orash', 'prash', 'qrash', 'rrash', 'srash', 'trash', 'urash', 'vrash', 'wrash', 'xrash', 'yrash', 'zrash', 'taash', 'tbash', 'tcash', 'tdash', 'teash', 'tfash', 'tgash', 'thash', 'tiash', 'tjash', 'tkash', 'tlash', 'tmash', 'tnash', 'toash', 'tpash', 'tqash', 'trash', 'tsash', 'ttash', 'tuash', 'tvash', 'twash', 'txash', 'tyash', 'tzash', 'trash', 'trbsh', 'trcsh', 'trdsh', 'tresh', 'trfsh', 'trgsh', 'trhsh', 'trish', 'trjsh', 'trksh', 'trlsh', 'trmsh', 'trnsh', 'trosh', 'trpsh', 'trqsh', 'trrsh', 'trssh', 'trtsh', 'trush', 'trvsh', 'trwsh', 'trxsh', 'trysh', 'trzsh', 'traah', 'trabh', 'trach', 'tradh', 'traeh', 'trafh', 'tragh', 'trahh', 'traih', 'trajh', 'trakh', 'tralh', 'tramh', 'tranh', 'traoh', 'traph', 'traqh', 'trarh', 'trash', 'trath', 'trauh', 'travh', 'trawh', 'traxh', 'trayh', 'trazh', 'trasa', 'trasb', 'trasc', 'trasd', 'trase', 'trasf', 'trasg', 'trash', 'trasi', 'trasj', 'trask', 'trasl', 'trasm', 'trasn', 'traso', 'trasp', 'trasq', 'trasr', 'trass', 'trast', 'trasu', 'trasv', 'trasw', 'trasx', 'trasy', 'trasz']

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("trash")) # aage peeche a-z insert
# Out:
# ['atrash', 'btrash', 'ctrash', 'dtrash', 'etrash', 'ftrash', 'gtrash', 'htrash', 'itrash', 'jtrash', 'ktrash', 'ltrash', 'mtrash', 'ntrash', 'otrash', 'ptrash', 'qtrash', 'rtrash', 'strash', 'ttrash', 'utrash', 'vtrash', 'wtrash', 'xtrash', 'ytrash', 'ztrash', 'tarash', 'tbrash', 'tcrash', 'tdrash', 'terash', 'tfrash', 'tgrash', 'thrash', 'tirash', 'tjrash', 'tkrash', 'tlrash', 'tmrash', 'tnrash', 'torash', 'tprash', 'tqrash', 'trrash', 'tsrash', 'ttrash', 'turash', 'tvrash', 'twrash', 'txrash', 'tyrash', 'tzrash', 'traash', 'trbash', 'trcash', 'trdash', 'treash', 'trfash', 'trgash', 'trhash', 'triash', 'trjash', 'trkash', 'trlash', 'trmash', 'trnash', 'troash', 'trpash', 'trqash', 'trrash', 'trsash', 'trtash', 'truash', 'trvash', 'trwash', 'trxash', 'tryash', 'trzash', 'traash', 'trabsh', 'tracsh', 'tradsh', 'traesh', 'trafsh', 'tragsh', 'trahsh', 'traish', 'trajsh', 'traksh', 'tralsh', 'tramsh', 'transh', 'traosh', 'trapsh', 'traqsh', 'trarsh', 'trassh', 'tratsh', 'traush', 'travsh', 'trawsh', 'traxsh', 'traysh', 'trazsh', 'trasah', 'trasbh', 'trasch', 'trasdh', 'traseh', 'trasfh', 'trasgh', 'trashh', 'trasih', 'trasjh', 'traskh', 'traslh', 'trasmh', 'trasnh', 'trasoh', 'trasph', 'trasqh', 'trasrh', 'trassh', 'trasth', 'trasuh', 'trasvh', 'traswh', 'trasxh', 'trasyh', 'traszh', 'trasha', 'trashb', 'trashc', 'trashd', 'trashe', 'trashf', 'trashg', 'trashh', 'trashi', 'trashj', 'trashk', 'trashl', 'trashm', 'trashn', 'trasho', 'trashp', 'trashq', 'trashr', 'trashs', 'trasht', 'trashu', 'trashv', 'trashw', 'trashx', 'trashy', 'trashz']

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("trash"))
# Out:
# {'btrash', 'frash', 'trasnh', 'trask', 'orash', 'trlsh', 'troash', 'atrash', 'htrash', 'tfrash', 'trhsh', 'tragh', 'traph', 'trasu', 'tragsh', 'traish', 'trashf', 'tcash', 'jtrash', 'trasz', 'tmrash', 'tryash', 'trashj', 'trashm', 'trashq', 'trashw', 'drash', 'tralsh', 'ntrash', 'trasch', 'trarsh', 'trdsh', 'trqash', 'utrash', 'trahs', 'trzsh', 'tvrash', 'traskh', 'dtrash', 'tranh', 'tramh', 'itrash', 'trashl', 'tirash', 'trlash', 'trgsh', 'trrash', 'trkash', 'tarsh', 'trasj', 'prash', 'tnrash', 'trpash', 'srash', 'trass', 'trasoh', 'tresh', 'trasgh', 'grash', 'traeh', 'tfash', 'trgash', 'trabh', 'trcsh', 'traxsh', 'trsash', 'tyrash', 'torash', 'trmash', 'vrash', 'tqash', 'ttash', 'tracsh', 'trjash', 'tsash', 'trasd', 'trashr', 'tratsh', 'zrash', 'trashx', 'tzrash', 'tjrash', 'trarh', 'trasx', 'trashu', 'tprash', 'trasdh', 'traslh', 'traseh', 'trashz', 'trasy', 'trah', 'trajh', 'trasrh', 'xtrash', 'tash', 'qtrash', 'tgrash', 'trash', 'trish', 'wrash', 'trfsh', 'trasi', 'rtash', 'trath', 'traih', 'tdash', 'turash', 'trtash', 'trdash', 'yrash', 'mrash', 'trashh', 'terash', 'trxash', 'trnash', 'trasih', 'trafsh', 'trashs', 'trjsh', 'trawsh', 'tbrash', 'trashv', 'tpash', 'trasn', 'trasb', 'tralh', 'etrash', 'tqrash', 'treash', 'trashk', 'nrash', 'tsrash', 'tradsh', 'tdrash', 'arash', 'tmash', 'trsh', 'trcash', 'tradh', 'trxsh', 'trtsh', 'trasha', 'trasc', 'twrash', 'ktrash', 'gtrash', 'trbash', 'trasxh', 'lrash', 'traqh', 'ltrash', 'tarash', 'trasm', 'trashn', 'thash', 'traso', 'tramsh', 'trase', 'trasa', 'rrash', 'transh', 'trashb', 'traqsh', 'trafh', 'trasg', 'trnsh', 'irash', 'trasp', 'trbsh', 'trrsh', 'truash', 'ttrash', 'traesh', 'trazsh', 'traoh', 'trasjh', 'vtrash', 'ztrash', 'trasv', 'traosh', 'trahh', 'tvash', 'wtrash', 'trasht', 'tjash', 'txrash', 'travh', 'trvash', 'twash', 'trast', 'trasq', 'trasah', 'thrash', 'traash', 'trashg', 'trosh', 'tkash', 'trssh', 'qrash', 'traxh', 'tzash', 'ytrash', 'hrash', 'tkrash', 'trasmh', 'traszh', 'brash', 'trashy', 'ftrash', 'trasyh', 'trasl', 'travsh', 'trasho', 'trach', 'trassh', 'traswh', 'trmsh', 'tyash', 'strash', 'trajsh', 'erash', 'mtrash', 'trhash', 'tnash', 'trvsh', 'trsah', 'trashi', 'traush', 'krash', 'xrash', 'jrash', 'trashd', 'ctrash', 'trasfh', 'trashc', 'trfash', 'tgash', 'trashp', 'tlrash', 'traysh', 'teash', 'trasf', 'tlash', 'trapsh', 'trwash', 'traksh', 'trasbh', 'trashe', 'ptrash', 'toash', 'trzash', 'trabsh', 'tbash', 'taash', 'trksh', 'trwsh', 'trazh', 'tras', 'trysh', 'tuash', 'txash', 'trakh', 'trasuh', 'trqsh', 'triash', 'urash', 'otrash', 'trasth', 'trasqh', 'trahsh', 'trasvh', 'trush', 'crash', 'trasr', 'trayh', 'trasw', 'tiash', 'rtrash', 'trawh', 'tcrash', 'trpsh', 'trasph', 'rash', 'traah', 'trauh'}

# %%
def edit2(word):
  return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("trash"))
# Out:
# {'traosha', 'tirpash', 'ntriash', 'trlawh', 'trafshc', 'trabsnh', 'trhavh', 'hrvash', 'ircash', 'trashox', 'rtrsah', 'trtashp', 'trjqash', 'qrahs', 'yratsh', 'araszh', 'trasme', 'twasp', 'tmradh', 'trbaqsh', 'trosc', 'axash', 'ibtrash', 'ttcsh', 'trgshv', 'ktrashh', 'xltrash', 'tfasjh', 'thrhsh', 'oqash', 'trhahh', 'teasuh', 'tzauh', 'trashqb', 'xtrashp', 'etrpsh', 'twass', 'traxsyh', 'wtrnsh', 'raih', 'tash', 'tdprash', 'aztrash', 'yhash', 'ztravh', 'tyrasht', 'ttrksh', 'tnashv', 'htrxash', 'ntrach', 'rrvash', 'rtkrash', 'trashct', 'ztrashw', 'trnasbh', 'trashmp', 'trjadh', 'ytrashh', 'trasihw', 'trlashd', 'sotrash', 'ifrash', 'rdtash', 'terashf', 'trkagsh', 'trarsnh', 'trawssh', 'traop', 'trakhn', 'tzrfsh', 'tlrvash', 'tgashc', 'tarashv', 'zerash', 'trgbsh', 'ctrazh', 'troasha', 'txlsh', 'sraseh', 'twrasvh', 'trazu', 'ztrpash', 'trvsnh', 'lhtrash', 'twmash', 'trasrnh', 'iraeh', 'xrabsh', 'trasnj', 'jtrashn', 'trfavh', 'trashmr', 'transyh', 'fyrash', 'trpkash', 'wtrasd', 'krashs', 'hrass', 'trjbsh', 'teasgh', 'trtansh', 'trsshz', 'trashbk', 'xtrdsh', 'mtrast', 'tras', 'tzrasz', 'turasjh', 'trasfbh', 'trcsi', 'utragh', 'trachz', 'trzshj', 'traka', 'tkosh', 'tsrashm', 'tramsy', 'tqashp', 'xtrashv', 'trskah', 'wtrpsh', 'ntrashx', 'tpramsh', 'tsreash', 'tralesh', 'crgsh', 'trtasy', 'trbagh', 'tyrasx', 'thrast', 'ttraih', 'trtfh', 'eyash', 'btfrash', 'tratsho', 'tcrasn', 'trfsdh', 'taaysh', 'tmas', 'tratsr', 'teaslh', 'trakshv', 'traqsha', 'trapsha', 'tlraoh', 'trashef', 'ngash', 'zrashz', 'traswxh', 'hrasa', 'trajfsh', 'tprafh', 'trbsqh', 'tahsh', 'crawsh', 'jtrasv', 'troaeh', 'dtradh', 'taerash', 'traesqh', 'trexh', 'tzrqsh', 'tlashq', 'tranrsh', 'tiratsh', 'traslhq', 'tdrasbh', 'tfashx', 'twatsh', 'terabh', 'terasr', 'tryhash', 'traschl', 'tracsyh', 'ttrasg', 'tlqrash', 'trkshc', 'trasndh', 'tdrajsh', 'tyasxh', 'gctrash', 'drass', 'gtrath', 'gtrasv', 'trashlk', 'trstsh', 'tlragh', 'trwoash', 'trmashj', 'atrauh', 'srashe', 'trtvash', 'nrasgh', 'tqrcash', 'trayse', 'sransh', 'erabh', 'tramih', 'tracsnh', 'tuasah', 'trazshx', 'tzavsh', 'trand', 'graush', 'trajshn', 'srzash', 'tvrasxh', 'ptrhash', 'trafnh', 'itrasyh', 'ctrasch', 'traslfh', 'arnash', 'tbasho', 'turwsh', 'tbrasc', 'trnh', 'traggsh', 'tresdh', 'qmash', 'traspnh', 'ttrsash', 'trrshr', 'tgakh', 'trgshw', 'traksh', 'cxash', 'trqaoh', 'turysh', 'mransh', 'tvase', 'trvfsh', 'itrasha', 'qtarsh', 'ltraswh', 'fruash', 'struash', 'trxvh', 'trpashj', 'trstash', 'tllsh', 'vrafh', 'trhh', 'trvsxh', 'ftrashe', 'trahy', 'ttrasph', 'itradsh', 'tprashs', 'abash', 'trahesh', 'trashne', 'gtramsh', 'trpahsh', 'trashsd', 'ntrasih', 'tarasc', 'tiashf', 'tashs', 'thrish', 'trfasbh', 'srashs', 'trarsgh', 'zrashv', 'hrajsh', 'tcrssh', 'tfrasm', 'trawdh', 'txrasy', 'tubsh', 'trxysh', 'trashjt', 'traask', 'trurh', 'atraszh', 'tirayh', 'trwasl', 'tlrxsh', 'orast', 'tlrashy', 'ttraash', 'rtask', 'ytaash', 'traswx', 'utkrash', 'tpashj', 'ojtrash', 'tralhz', 'trosm', 'turjsh', 'tfqrash', 'tkanh', 'tfafh', 'lstrash', 'crashe', 'trnashn', 'tcragh', 'travsrh', 'taasa', 'trashqj', 'tlrush', 'tfazsh', 'trasvqh', 'tcgrash', 'trashik', 'mtdash', 'trbaeh', 'itrasm', 'prtash', 'ktsash', 'trasel', 'tralszh', 'ktravsh', 'ktrabsh', 'tjasw', 'itrfsh', 'trhph', 'traszhm', 'traserh', 'hrxsh', 'txrasg', 'ktrasha', 'tradsph', 'tzrashi', 'ztrarsh', 'hrasht', 'tryszh', 'trasfyh', 'rtush', 'traqsg', 'thashk', 'thyash', 'tjaesh', 'ttaosh', 'etrahh', 'tkash', 'traeshj', 'trauo', 'ftrgsh', 'tvraish', 'tgraslh', 'tgraskh', 'tgrase', 'terath', 'tkpash', 'ttsash', 'trpshc', 'traocsh', 'trlsj', 'trxaosh', 'torasy', 'trqgsh', 'tracszh', 'trastdh', 'ntrasht', 'wtgrash', 'drashd', 'trnasd', 'tsrtsh', 'trzansh', 'tyrashm', 'lrauh', 'trssu', 'rtashn', 'tobsh', 'tkrasch', 'mrasjh', 'trdbsh', 'trfasht', 'tirjsh', 'twasq', 'tvrafh', 'tlraesh', 'txraush', 'btrvash', 'trauhv', 'tlrasl', 'btrahh', 'trgsyh', 'trkaysh', 'htralh', 'traasxh', 'vraxsh', 'wrasgh', 'tratshh', 'tcrasw', 'tqabsh', 'zztrash', 'toasr', 'trqashp', 'tqrashj', 'mrg ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is already correctly spelt")
    return

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "pla"
print(correct_spelling(word, vocabs, word_probas))
# Out:
# [('ply', 0.0625), ('play', 0.0625)]

# %%
word = "famile"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best_ix = np.argmax(probs)
  correct = corrections[best_ix][0]
  print(f"{correct} is suggested for {word}")

# %%
class SpellChecker(object):

  def __init__(self, corpus_file_path):
    with open(corpus_file_path, "r") as file:
      lines = file.readlines()
      words = []
      for line in lines:
        words += re.findall(r'\w+', line.lower())

    self.vocabs = set(words)
    self.word_counts = Counter(words)
    total_words = float(sum(self.word_counts.values()))
    self.word_probas = {word: self.word_counts[word] / total_words for word in self.vocabs}

  def _level_one_edits(self, word):
    letters = string.ascii_lowercase
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [l + r[1:] for l,r in splits if r]
    swaps = [l + r[1] + r[0] + r[2:] for l, r in splits if len(r)>1]
    replaces = [l + c + r[1:] for l, r in splits if r for c in letters]
    inserts = [l + c + r for l, r in splits for c in letters]

    return set(deletes + swaps + replaces + inserts)

  def _level_two_edits(self, word):
    return set(e2 for e1 in self._level_one_edits(word) for e2 in self._level_one_edits(e1))

  def check(self, word):
    candidates = self._level_one_edits(word) or self._level_two_edits(word) or [word]
    valid_candidates = [w for w in candidates if w in self.vocabs]
    return sorted([(c, self.word_probas[c]) for c in valid_candidates], key=lambda tup: tup[1], reverse=True)

# %%
checker = SpellChecker("/content/demo.txt")

# %%
checker.check("mary")
# Out:
# []
